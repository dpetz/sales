# %% [markdown]
# ```
# grep -e '01/03/2012' -e 'Invoice' Liquor_Sales.csv | cat >day_1.csv
# ```

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
from sales_util import read_liquor_csv, infer_relation_cardinalities
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = read_liquor_csv('day_1')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10147 entries, 0 to 10146
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Invoice_Item_Number  10147 non-null  string
#  1   Date                 10147 non-null  category
#  2   Store_Number         10147 non-null  category
#  3   Store_Name           10147 non-null  category
#  4   Address              10147 non-null  category
#  5   City                 10147 non-null  category
#  6   Zip_Code             10147 non-null  category
#  7   Store_Location       10147 non-null  category
#  8   County_Number        10121 non-null  category
#  9   County               10147 non-null  category
#  10  Category             10147 non-null  category
#  11  Category_Name        10147 non-null  category
#  12  Vendor_Number        10147 non-null  category
#  13  Vendor_Name          10147 non-null  category
# ...

# %%
df.City.cat.categories
# Out:
# Index(['ALDEN', 'ALLISON', 'ALTOONA', 'AMES', 'ANAMOSA', 'ANITA', 'ANKENY',
#        'ARMSTRONG', 'ARNOLDS PARK', 'ATLANTIC',
#        ...
#        'TRIPOLI', 'URBANA', 'URBANDALE', 'WATERLOO', 'WAVERLY',
#        'WEST BURLINGTON', 'WEST DES MOINES', 'WEST POINT', 'WILLIAMSBURG',
#        'WINDSOR HEIGHTS'],
#       dtype='string', length=101)

# %%
df.apply(pd.Series.nunique)
# Out:
# Invoice_Item_Number    10147
# Date                       1
# Store_Number             216
# Store_Name               215
# Address                  215
# City                     101
# Zip_Code                 115
# Store_Location           199
# County_Number             49
# County                    50
# Category                  67
# Category_Name             67
# Vendor_Number             50
# Vendor_Name               50
# Item_Number             1166
# Item_Description         826
# Pack                      10
# Bottle_Volume_ml          16
# State_Bottle_Cost        587
# State_Bottle_Retail      614
# Bottles_Sold              30
# Sale_Dollars            2280
# Volume_Sold_Liters        78
# Volume_Sold_Gallons       78
# dtype: int64

# %%
df.iloc[0]
# Out:
# Invoice_Item_Number                            S03392100057
# Date                                    2012-01-03 00:00:00
# Store_Number                                           3920
# Store_Name             Smokin' Joe's #11 Tobacco and Liquor
# Address                                   1606 CAMANCHE AVE
# City                                                CLINTON
# Zip_Code                                              52732
# Store_Location                 POINT (-90.204748 41.827845)
# County_Number                                            23
# County                                              Clinton
# Category                                            1031100
# Category_Name                               100 PROOF VODKA
# Vendor_Number                                           300
# Vendor_Name                    Mccormick Distilling Company
# Item_Number                                           36886
# Item_Description                            Mccormick Vodka
# ...

# %%
pd.options.display.max_columns = None
df[df['Store_Number'] == 3920]
# Out:
#      Invoice_Item_Number       Date Store_Number  \
# 0           S03392100057 2012-01-03         3920
# 199         S03392100044 2012-01-03         3920
# 265         S03392100024 2012-01-03         3920
# 309         S03392100031 2012-01-03         3920
# 324         S03392100040 2012-01-03         3920
# ...                  ...        ...          ...
# 9501        S03392100004 2012-01-03         3920
# 9578        S03392100051 2012-01-03         3920
# 9657        S03392100065 2012-01-03         3920
# 9751        S03392100079 2012-01-03         3920
# 9804        S03392100023 2012-01-03         3920
#
#                                 Store_Name            Address     City  \
# 0     Smokin' Joe's #11 Tobacco and Liquor  1606 CAMANCHE AVE  CLINTON
# 199   Smokin' Joe's #11 Tobacco and Liquor  1606 CAMANCHE AVE  CLINTON
# 265   Smokin' Joe's #11 Tobacco and Liquor  1606 CAMANCHE AVE  CLINTON
# 309   Smokin' Joe's #11 Tobacco and Liquor  1606 CAMANCHE AVE  CLINTON
# ...

# %%
df[df['Item_Number'] == '36886']
# Out:
#      Invoice_Item_Number       Date Store_Number  \
# 0           S03392100057 2012-01-03         3920
# 112         S03395200083 2012-01-03         2507
# 246         S03405200029 2012-01-03         2954
# 1747        S03391300118 2012-01-03         3612
# 1931        S03391800005 2012-01-03         4480
# 2537        S03399800004 2012-01-03         3970
# 2560        S03393400035 2012-01-03         2624
# 2579        S03383900014 2012-01-03         2555
# 3101        S03410900116 2012-01-03         2649
# 3606        S03389300014 2012-01-03         3858
# 4890        S03396400023 2012-01-03         4312
# 4984        S03408300015 2012-01-03         2614
# 5121        S03393900031 2012-01-03         3963
# 5569        S03408100011 2012-01-03         3162
# 6518        S03393600008 2012-01-03         4040
# 7696        S03407400012 2012-01-03         2962
# 7971        S03382200006 2012-01-03         4584
# 8446        S03395800113 2012-01-03         2616
# ...
